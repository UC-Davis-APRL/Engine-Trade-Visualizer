# %%
import numpy as np
import rocketcea 
import pint
import time
import plotly.express as px
import plotly.graph_objects as go
import pandas as pd
from plotly.subplots import make_subplots
pint.__version__  
from pint import UnitRegistry

from rocketcea.cea_obj import CEA_Obj
from functools import cached_property

# %%
#Generating CEA object and exit velocity (67% overall efficiency)
C = CEA_Obj(oxName="LOX", fuelName="Kerosene")
#V_exit = C.get_Isp(Pc=360, MR=1.35, eps=3.789, frozen=1) * 0.80 * 9.81
V_exit = 1765.8

#Calculate maximum possible mass flow/thrust based on ALI CdA and NF Setpoint
P_c=300 #psia
OF=1.22
CdA_combined_LOX = 2.137E-04 #ft^2
CdA_combined_KERO = 2.000E-04 #ft^2

#Assume LOX at 90 K, KERO at room temp
rho_LOX = 2.222 #slugs/ft^3
rho_KERO = 1.591 #slugs/ft^3

mdot_max_LOX = CdA_combined_LOX*np.sqrt(2*rho_LOX*144*(1000-P_c)) * 14.5939029
mdot_max_KERO = CdA_combined_KERO*np.sqrt(2*rho_KERO*144*(1000-P_c)) * 14.5939029 

print(f"Maximum LOX Massflow: {mdot_max_LOX} kg/s")
print(f"Corresponding KERO Massflow: {mdot_max_LOX/OF} kg/s \n")

print(f"Maximum KERO Massflow: {mdot_max_KERO} kg/s")
print(f"Corresponding LOX Massflow: {mdot_max_KERO*OF} kg/s")
# Out:
# Maximum LOX Massflow: 2.087340336818481 kg/s
# Corresponding KERO Massflow: 1.7109347023102301 kg/s
#
# Maximum KERO Massflow: 1.653034058621466 kg/s
# Corresponding LOX Massflow: 2.0167015515181883 kg/s

# %% [markdown]
# As seen in the above results, the maximum total massflow is limited by the kerosene line, as the corresponding kerosene massflow for case 1 is greater than the maximum massflow as seen in case 2.

# %%
#Initializaing Core Variables and Lists
mdot_max_TOTAL = mdot_max_KERO + mdot_max_KERO*OF

mdot_arr = np.linspace(0, mdot_max_TOTAL, num=51)
thrust_arr = V_exit*mdot_arr
tburn_arr = np.linspace(20, 0, num=51)

m_dry_const = 55 #kg

#Initializing altitude
apogee_altitude = [[0 for x in thrust_arr] for y in tburn_arr]
TWR_arr = [[0 for x in thrust_arr] for y in tburn_arr]
m_wet_arr = [[0 for x in thrust_arr] for y in tburn_arr]
m_dry_arr = [[0 for x in thrust_arr] for y in tburn_arr]
burnout_arr = [[0 for x in thrust_arr] for y in tburn_arr]

accel_arr = [[0 for x in thrust_arr] for y in tburn_arr]
maxAccel = 0

# %%
#Integrator Function Definition

def altitude_integrator(thrust, tburn, OF, m_dry_const, mdot, dt, drag=True):
    maxAccel = 0

    #Initialize Lists and Variables
    x_arr = []
    t_arr = []
    v = 0
    x = 0
    t = 0
    m_prop_total = mdot * tburn

    #Aerodynamic Variables
    Cf = 0
    Cf_fins = 0
    rho_ATM = 1.225 #kg/m^3
    mu_ATM = 1.789E-05 #Pa*s

    ### CALCULATIONS FOR VARIABLES CHANGING DUE TO TANK LENGTH CHANGES ###

    #Assume LOX at 90 K, KERO at room temp
    rho_LOX = 1145.1717 #kg/m^3
    mdot_LOX = mdot/((1/OF)+1)
    m_LOX = mdot_LOX * tburn
    V_LOX = (m_LOX/rho_LOX)*1.15

    rho_KERO = 819.9677 #kg/m^3
    mdot_KERO = mdot/(OF+1)
    m_KERO = mdot_KERO * tburn
    V_KERO = (m_KERO/rho_KERO)*1.15

    #Body length calculation based on needed tank length, assuming all other airframe sections constant length
    Diam = 0.203 #m
    L_const = 3.81 #m
    L_LOXT = V_LOX/((np.pi*Diam**2)/4)
    L_KEROT = V_KERO/((np.pi*Diam**2)/4)

    L = L_const + L_LOXT + L_KEROT #m

    A_wet = (2*np.pi*Diam*L/2) + 0.299542230065 #m^2 (body contribution + precalculated nosecone contribution)
    R_s = 2.0E-05 #m
    R_d_crit = 51*(R_s/L)**(-1.039)

    #Tank dry mass contribution
    t = 0.00635 #m (0.25 inch wall thickness)
    Diam_Inner = Diam - (2*t)
    rho_AL = 2700 #kg/m^3
    m_dry_LOXT = rho_AL*L_LOXT*((np.pi*Diam**2)/4 - (np.pi*Diam_Inner**2)/4)
    m_dry_KEROT = rho_AL*L_KEROT*((np.pi*Diam**2)/4 - (np.pi*Diam_Inner**2)/4)

    m_dry_total = m_dry_const + m_dry_KEROT + m_dry_LOXT
    m = m_prop_total + m_dry_total
    m_wet = m
    TWR = thrust/(m_wet*9.81)

    #For Fins
    L_fins = 0.305 #m
    A_wet_fins = 0.28512 #m^2 (contribution of 4 fins)
    R_s_fins = 2.0E-05 #m
    R_d_crit_fins = 51*(R_s/L)**(-1.039)

    #Setup for burnout check
    t_prev = 0
    x_burnout = 0

    while v >=0:
            #Checks for burnout
            if (t >= tburn) and (t_prev < tburn):
                x_burnout = x
            elif tburn == 0:
                x_burnout = 0

            #Sets thrust and massflow to 0 at end of burn
            if t > tburn:
                thrust = 0
                mdot = 0
            
            #Update mass
            m = m-(mdot*dt) #kg

            ### BODY/NOSECONE SKIN FRICTION DRAG CALCULATION ###

            if drag:
                R_d = (rho_ATM * v * L)/(mu_ATM)
                M = v/343 #m/s

                #Reynolds Number Regimes
                if R_d < 1.0E4:
                    Cf = 1.48E-02
                elif (1.0E4 <= R_d) & (R_d <= R_d_crit):
                    Cf = 1/((1.5*np.log(R_d)-5.6)**2)
                elif R_d_crit < R_d:
                    Cf = 0.032*(R_s/L)**0.2
                else:
                    Cf = 0

                #Mach Number Regimes
                if M < 1:
                    Cfc = Cf*(1 - 0.1*M**2)
                elif (1 <= M) & (R_d < R_d_crit):
                    Cfc = Cf/((1+0.15*M**2)**0.58)
                elif (1 <= M) & (R_d > R_d_crit):
                    Cfc = Cf/(1+0.18*M**2)

                D = Cfc*0.5*rho_ATM*(v**2)*A_wet
            else:
                D=0

            ### FINS SKIN FRICTION DRAG CALCULATION ###

            if drag:
                R_d_fins = (rho_ATM * v * L_fins)/(mu_ATM)

                #Reynolds Number Regimes
                if R_d_fins < 1.0E4:
                    Cf_fins = 1.48E-02
                elif (1.0E4 <= R_d_fins) & (R_d_fins <= R_d_crit_fins):
                    Cf_fins = 1/((1.5*np.log(R_d_fins)-5.6)**2)
                elif R_d_crit_fins < R_d_fins:
                    Cf_fins = 0.032*(R_s_fins/L_fins)**0.2
                else:
                    Cf_fins = 0

                #Mach Number Regimes
                if M < 1:
                    Cfc_fins = Cf_fins*(1 - 0.1*M**2)
                elif (1 <= M) & (R_d_fins < R_d_crit_fins):
                    Cfc_fins = Cf_fins/((1+0.15*M**2)**0.58)
                elif (1 <= M) & (R_d_fins > R_d_crit_fins):
                    Cfc_fins = Cf_fins/(1+0.18*M**2)

                D_fins = Cfc_fins*0.5*rho_ATM*(v**2)*A_wet_fins
            else:
                D_fins = 0

            #Update velocity
            v_old = v
            dv = ((thrust/m) - 9.81 - (D/m) - (D_fins/m))*dt
            v = v + dv
            #Update position
            dx = ((v+v_old)/2)*dt
            x = x + dx
            t_prev = t
            t = t + dt

            if maxAccel < (dv/dt):
                maxAccel = dv/dt
            x_arr.append(x)
            t_arr.append(t)

    #print(f"Altitude at Apogee: {x}")
    return(x, x_arr, t_arr, TWR, m_wet, m_dry_total, x_burnout, maxAccel)

# %%
#Running the Full Estimator
dt = 0.01

#Loop through entire matrix
for i, thrust in enumerate(thrust_arr):
    for j, tburn in enumerate(tburn_arr):
        mdot = mdot_arr[i]
        m_prop_total = mdot * tburn

        x, x_arr, t_arr, TWR, m_wet, m_dry_total, x_burnout, maxAccel = altitude_integrator(thrust = thrust, tburn = tburn, OF = OF, m_dry_const = m_dry_const, mdot = mdot, dt = dt)
        
        apogee_altitude[j][i] = x
        TWR_arr[j][i] = TWR
        m_wet_arr[j][i] = m_wet
        m_dry_arr[j][i] = m_dry_total
        burnout_arr[j][i] = x_burnout
        accel_arr[j][i] = maxAccel / 9.81 #Converting to unit of g
        #print(f"Thrust:{thrust} | Burn Time:{tburn} | Altitude:{x}")

# %%
#Plotting

#Heat Map
fig1 = px.imshow(apogee_altitude, 
                labels=dict(x = "Thrust (N)",
                            y = "Burn Time (s)",
                            color = "Altitude (m)"),
                            x = thrust_arr,
                            y = tburn_arr,
                            aspect = "auto",
                            origin = "lower",
                            title="Apogee Altitude vs Thrust & Burn Time",
                            )

fig1.update_traces(customdata = np.stack(
    (TWR_arr, m_wet_arr, m_dry_arr, burnout_arr, accel_arr),
    axis=-1
))

fig1.update_traces(
    hovertemplate = 
    "Thrust: %{x:.2f} N<br>"
    "Burn Time: %{y:.1f} s<br>"
    "Altitude: %{z:.2f} m<br>"
    "Burnout Altitude: %{customdata[3]:.2f} m<br>"
    "TWR: %{customdata[0]:.2f} <br>"
    "Wet Mass: %{customdata[1]:.2f} kg<br>"
    "Dry Mass: %{customdata[2]:.2f} kg<br>"
    "Max Acceleration: %{customdata[4]:.2f} G<br>"
    "<extra></extra>"
)

fig1.update_layout(
        width=800,
        height=700
    )

fig1.show()

#Surface Map
fig2 = go.Figure(data = go.Surface(z = apogee_altitude,
                                x = thrust_arr,
                                y = tburn_arr,
                                customdata = np.stack((TWR_arr, m_wet_arr, m_dry_arr, burnout_arr), axis=-1),
                                contours = {"x": {"show": False, "start": 889.6297399465218, "end": 3199.8070562191997, "size": (3199.8070562191997-889.6297399465218)/20},
                                                           "y": {"show": False, "start": 5, "end": 20, "size": (20-5)/21},
                                                           "z": {"show": True, "start": 0, "end": 20000, "size": 1000}},
                                hovertemplate = (
                                    "Thrust: %{x:.2f} N<br>"
                                    "Burn Time: %{y:.1f} s<br>"
                                    "Altitude: %{z:.2f} m<br>"
                                    #"Burnout Altitude: %{customdata[3]:.2f} m<br>"
                                    #"TWR: %{customdata[0]:.2f} <br>"
                                    #"Wet Mass: %{customdata[1]:.2f} kg<br>"
                                    #"Dry Mass: %{customdata[2]:.2f} kg<br>"
                                    "<extra></extra>"
                                    ),
                                ))

fig2.update_layout(
        title="Apogee Altitude vs Thrust & Burn Time",
        scene = dict(
                      xaxis=dict(
                          title=dict(
                              text="Thrust (N)"
                          )
                      ),
                      yaxis=dict(
                          title=dict(
                              text="Burn Time (s)"
                          )
                      ),
                      zaxis=dict(
                          title=dict(
                              text="Apogee Altitude (m)"
                          )
                      ),
                    ),
        width=800,
        height=700,
    )

fig2.update_scenes(xaxis_autorange="reversed")
fig2.update_scenes(yaxis_autorange="reversed")

fig2.show()

# fig2_TWR = go.Figure(data = go.Surface(z = TWR_arr,
#                                 x = thrust_arr,
#                                 y = tburn_arr,
#                                 contours = {"x": {"show": False, "start": 889.6297399465218, "end": 3199.8070562191997, "size": (3199.8070562191997-889.6297399465218)/20},
#                                                            "y": {"show": False, "start": 5, "end": 20, "size": (20-5)/21},
#                                                            "z": {"show": True, "start": 0, "end": 10, "size": 1}},
#                                 ))

# fig2_TWR.update_layout(
#         title="THrust to Weight Ratio vs Thrust & Burn Time",
#         scene = dict(
#                       xaxis=dict(
#                           title=dict(
#                               text="Thrust (N)"
#                           )
#                       ),
#                       yaxis=dict(
#                           title=dict(
#                               text="Burn Time (s)"
#                           )
#                       ),
#                       zaxis=dict(
#                           title=dict(
#                               text="TWR"
#                           )
#                       ),
#                     ),
#         width=800,
#         height=700,
#     )

# fig2_TWR.update_scenes(xaxis_autorange="reversed")
# fig2_TWR.update_scenes(yaxis_autorange="reversed")

# fig2_TWR.show()

# %%
#Example altitude_integrator() run
x, x_arr, t_arr, TWR, m_wet, m_dry_total, x_burnout, maxAccel = altitude_integrator(thrust = 2157, tburn = 10, OF = OF, m_dry_const = 50, mdot = 1.2918, dt = 0.001)
x_dragless, x_arr_dragless, t_arr_dragless, TWR_dragless, m_wet_dragless, m_dry_total_dragless, x_burnout_dragless = altitude_integrator(thrust = 2157, tburn = 10, OF = OF, m_dry_const = 50, mdot = 1.2918, dt = 0.001, drag = False)

fig3 = go.Figure(
    layout = go.Layout(
        title=go.layout.Title(text="Vehicle Altitude vs Time | Thrust = 2157 N | Burn Time = 10 s"),
        width = 800,
        height = 700
    )
)
fig3.add_trace(go.Scatter(x = t_arr, y = x_arr, mode = "lines", name = "With Drag"))
fig3.add_trace(go.Scatter(x = t_arr_dragless, y = x_arr_dragless, mode="lines", name="Without Drag"))

fig3.update_layout(
    xaxis_title = "Time Since Launch (s)",
    yaxis_title = "Altitude (m)"
)

fig3.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 3
#       1 #Example altitude_integrator() run
#       2 x, x_arr, t_arr, TWR, m_wet, m_dry_total, x_burnout, maxAccel = altitude_integrator(thrust = 2157, tburn = 10, OF = OF, m_dry_const = 50, mdot = 1.2918, dt = 0.001)
# ----> 3 x_dragless, x_arr_dragless, t_arr_dragless, TWR_dragless, m_wet_dragless, m_dry_total_dragless, x_burnout_dragless = altitude_integrator(thrust = 2157, tburn = 10, OF = OF, m_dry_const = 50, mdot = 1.2918, dt = 0.001, drag = False)
#       5 fig3 = go.Figure(
#       6     layout = go.Layout(
#       7         title=go.layout.Title(text="Vehicle Altitude vs Time | Thrust = 2157 N | Burn Time = 10 s"),
#    (...)     10     )
#      11 )
#      12 fig3.add_trace(go.Scatter(x = t_arr, y = x_arr, mode = "lines", name = "With Drag"))
#
# ValueError: too many values to unpack (expected 7)

# %%
plot_div1 = fig1.to_html(full_html=False, include_plotlyjs='cdn')
plot_div2 = fig2.to_html(full_html=False, include_plotlyjs='cdn')
plot_div3 = fig3.to_html(full_html=False, include_plotlyjs='cdn')

with open("Altitude Estimator V1 Output.html", "a") as f:
    f.truncate(0)
    f.write(plot_div1)
    f.write(plot_div2)
    f.write(plot_div3)
